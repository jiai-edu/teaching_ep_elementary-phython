# %%
from PackagingTest import TestClass as tc

a = []
a.append(tc(1, "テスト1"))
a.append(tc(2, "テスト2"))

for i in a:
  print("===== Class =====")
  print("code --> " + str(i.code))
  print("name --> " + i.name)

# %%
import PackagingTest as pt

b = []
b.append(pt.TestClass(1, "テスト1"))
b.append(pt.TestClass(2, "テスト2"))

for i in a:
  print("===== Class =====")
  print("code --> " + str(i.code))
  print("name --> " + i.name)

# %%
c = []
c.append(pt.City('Japan', 'Tokyo'))
c.append(pt.City('USA', 'Washington, D.C.'))
 
for i in c:
  print('===== Class =====')
  print('country_name --> ' + i.country_name)
  print('city_name --> ' + i.city_name)

# %%
d = pt.NewStyleClass()
d.test_method("method call")

# %%
'''
=====
PackagingTest.py
=====

class TestClass:
  def __init__(self, code, name):
    self.code = code
    self.name = name


class Country:
  def __init__(self, country_name):
    self.country_name = country_name
 
 
class City(Country):
  def __init__(self, country_name, city_name):
    super().__init__(country_name)
    self.city_name = city_name


class NewStyleClassBase(object):
  def test_method(self, msg):
    print('NewStyleClassBase: {}'.format(msg))
 
 
class NewStyleClass(NewStyleClassBase):
  def test_method(self, msg):
    print('NewStyleClass: {}'.format(msg))
    super().test_method(msg)
'''
