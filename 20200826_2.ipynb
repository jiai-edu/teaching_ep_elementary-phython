# %%
import matplotlib.pyplot as plt
#import seaborn as sns
import math
import numpy as np

x = range(0,1000)
hz1 = 14
hz2 = 15

max_x = max(x)
y3 = np.array([math.sin(math.radians((360*hz1)/max_x * ms)) for ms in x])
#print(y3)
#y4 = np.array([math.sin(math.radians((360*hz2)/max_x * ms)) for ms in x])

#sns.set()

plt.figure(figsize=(15.0, 6.0))

plt.plot(x, y3, label='14hz',linestyle="--", color='slateblue')
#plt.plot(x, y4, label='15hz',linestyle="-.", color='orchid')
#plt.plot(x, y3+y4, label='mix', color='red')

plt.legend()  # 凡例を表示する
plt.xlabel("millisecond")  # 横軸ラベル
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

K = 100
i = 0
x = range(0,K)
y5 = np.array(4)


a = 1
for i in range(1,K):
    a = a + (1/(1+2*i))*((-1)**i)
    #print(a*4)
    y5 = np.append(y5, a*4)
    #print(y5)

#print(y5)





plt.figure(figsize=(31.0, 15.0))

plt.plot(x, y5, label='y5',linestyle="-", color='slateblue')

plt.legend()  # 凡例を表示する
plt.xlabel("millisecond")  # 横軸ラベル
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas.util.testing as tm

def function(a):
  L = a.size
  #print(a)
  #print(L)
  z = np.array(4)
  k = 1
  i = 0
  for i in range(1,L):
    k = k + (1/(1+2*i))*((-1)**i)
    z = np.append(z, k*4)

  #print(k)
  return z

x = np.linspace(1, 10000, 10000)
y = function(x)
#print(y)

sns.set()
plt.figure(figsize=(31.0, 15.0))

plt.plot(x, y)
plt.grid(True)
plt.show()

# %%
def function2(a):
  L = a.size
  z = np.array(1)
  k = 1
  i = 0
  for i in range(0,L-1):
    k = k + (1/(1+2*(L-i))*((-1)**(L-i)
    z = np.append(z, k*4)
  return z

x2 = np.linspace(1, 100, 100)
y2 = function2(x2)
#print(y)

sns.set()
plt.plot(x2, y2)
plt.show()
# Out:
#   File "<ipython-input-65-4e47a96e4afa>", line 8
#     z = np.append(z, k*4)
#     ^
# SyntaxError: invalid syntax

# %%
L = 10
x = [i for i in range(L*(-1),L+1)] 
#print(len(x))
y = [i for i in range(L*(-1),L+1)] 

a = 0
b = 0
d = [[x[0],y[0]]]
for b in range(0, len(y)):
  for a in range(0, len(x)):
    d = d + [[x[a],y[b]]]
d = d[1:len(d)]
#print(d)
#print(len(d))


contourf

#c = [([x[a], y[b]] for a in range(0, len(x)+1)) for b in range(0, len(y)+1)]
#print(c)

#z = x + yj
#z = z**2 + c
# Out:
# 21
# 441

# %%
import matplotlib
matplotlib.use('Agg') #under my ssh environment,the matplotlib cannnot work as usual so i need matplotlib.use('Agg')
import numpy as np
import matplotlib.pyplot as plt

# the fundamental heart gragh  grath00

t = np.linspace(0, 2 * 3.141, 100)
print(t)

sin1 = np.sin(t)
#print(sin1)

cos1 = np.cos(t)
#print(cos1)

cos2 = np.cos(2 * t)
#print(cos2)

cos3 = np.cos(3 * t)
#print(cos3)

cos4 = np.cos(4 * t)
#print(cos4)

gragh_00 =( sin1 ** 3 + ( 13 * cos1 - 5 * cos2 - 2 * cos3 - cos4 ) * 1j/ 15 ) * 4 / 8
#plot
plt.plot(np.real(gragh_00 * 7 / 8 ), np.imag(gragh_00 * 7 /8), linewidth =4, color="red")
# copy heart gragh 24 times

# making point array
point_list =  [[a -2 + ( b - 2 ) * 1j] for a in range(5) for b in range(5)]
point_list.remove([0j])
point_array = np.array(point_list)

for i in range(24):
        gragh_0i = point_array[i] - 1j * gragh_00 * (point_array[i] / np.absolute(point_array[i]))
        plt.plot(np.real(gragh_0i * 7 / 8 ), np.imag(gragh_0i * 7 /8), linewidth =4, color="red")


plt.axis('equal') #without this command matplot change axi's ratio
plt.savefig('heart.png')
# Out:
# [0.         0.06345455 0.12690909 0.19036364 0.25381818 0.31727273
#  0.38072727 0.44418182 0.50763636 0.57109091 0.63454545 0.698
#  0.76145455 0.82490909 0.88836364 0.95181818 1.01527273 1.07872727
#  1.14218182 1.20563636 1.26909091 1.33254545 1.396      1.45945455
#  1.52290909 1.58636364 1.64981818 1.71327273 1.77672727 1.84018182
#  1.90363636 1.96709091 2.03054545 2.094      2.15745455 2.22090909
#  2.28436364 2.34781818 2.41127273 2.47472727 2.53818182 2.60163636
#  2.66509091 2.72854545 2.792      2.85545455 2.91890909 2.98236364
#  3.04581818 3.10927273 3.17272727 3.23618182 3.29963636 3.36309091
#  3.42654545 3.49       3.55345455 3.61690909 3.68036364 3.74381818
#  3.80727273 3.87072727 3.93418182 3.99763636 4.06109091 4.12454545
#  4.188      4.25145455 4.31490909 4.37836364 4.44181818 4.50527273
#  4.56872727 4.63218182 4.69563636 4.75909091 4.82254545 4.886
#  4.94945455 5.01290909 5.07636364 5.13981818 5.20327273 5.26672727
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

#-5〜5の整数配列を生成
x1 = np.arange(-5, 6)
y1 = np.arange(-5, 6)
#print(x,y)

#格子点座標の作成
X1, Y1 = np.meshgrid(x1, y1)

#格子点ごとのデータを作成
data = X1**2 - Y1**2

#等高線をプロット
plt.contourf(X1, Y1, data)

#画像の表示
plt.show()

# %%
x2 = np.arange(-100, 101)
y2 = np.arange(-100, 101)

X2, Y2 = np.meshgrid(x2, y2)

data = X2**2 - Y2**2

plt.contourf(X2, Y2, data)

plt.show()

# %%
import math
print(math.pi)
print(math.pi * 1000000)
print(math.pi * 1000000000000000)
# Out:
# 3.141592653589793
# 3141592.653589793
# 3141592653589793.0

# %%
K = 10
x = [0]
y = [0]

for i in range(0,K):
  k = 10**i
  lmax = k * np.tan(math.pi / k)
  x = np.append(x,lmax)
  lmin = k * np.sin(math.pi / k)
  y = np.append(y,lmin)
  #print(i,lmax,lmin)

X = x[1:len(x)]
Y = y[1:len(y)]
print(X,Y)
# Out:
# [-1.22464680e-16  3.24919696e+00  3.14262660e+00  3.14160299e+00
#   3.14159276e+00  3.14159265e+00  3.14159265e+00  3.14159265e+00
#   3.14159265e+00  3.14159265e+00] [1.22464680e-16 3.09016994e+00 3.14107591e+00 3.14158749e+00
#  3.14159260e+00 3.14159265e+00 3.14159265e+00 3.14159265e+00
#  3.14159265e+00 3.14159265e+00]

# %%
class Mandelbrot:
    def __init__(self, M, maxItr):
        self.M = M
        self.maxItr = maxItr

    def Calc(self, re, im): # re, im: 2d Array 
        x = 0.0
        y = 0.0

        for i in range(self.maxItr):
            if x**2 + y*2 > self.M:
                return i
            x_ = x**2 - y**2 + re
            y_ = 2*x*y + im
            x, y = x_, y_
        return self.maxItr


M = 10000000
maxItr = 255
Mand = Mandelbrot(M, maxItr)

x_lower = -2.5
x_upper = 1.1
y_lower = -1.8
y_upper = 1.8
pixel = 1000
z = [[0 for m in range(pixel+1)] for n in range(pixel+1)]
for i in range(pixel+1):
    re = x_lower + (x_upper - x_lower)/pixel * i 
    for j in range(pixel+1):
        im = y_lower + (y_upper - y_lower)/pixel * j
        z[j][i] = Mand.Calc(re, im)


x = np.arange(pixel+1)
y = np.arange(pixel+1)
Z = np.array(z)
X, Y = np.meshgrid(x, y)

plt.rcParams['figure.figsize'] = 20,20
plt.gca().set_aspect('equal', adjustable='box')
plt.pcolor(X, Y, Z)
plt.colorbar()
plt.hot()
plt.xlabel('Re', fontsize=22)
plt.ylabel('Im', fontsize=22)
plt.xticks(color="None")
plt.yticks(color="None")
plt.tick_params(length=0)
plt.show()

# %%
class Julia:
    def __init__(self, M, maxItr, c_r, c_i):
        self.M = M
        self.maxItr = maxItr
        self.c_r = c_r
        self.c_i = c_i

    def Calc(self, r, i): # re, im: 2d Array 
        z_r = r
        z_i = i

        for i in range(self.maxItr):
            if z_r**2 + z_i*2 > self.M:
                return i
            z_r_ = z_r**2 - z_i**2 + self.c_r
            z_i_ = 2*z_r*z_i + self.c_i
            z_r, z_i = z_r_, z_i_
        return self.maxItr


import numpy as np
import matplotlib.pyplot as plt

M = 10000000
maxItr = 255
c_r = 0.06
c_i = -0.70

J = Julia(M, maxItr, c_r, c_i)

x_lower = -2.0
x_upper = 2.0
y_lower = -1.5
y_upper = 1.5
pixel = 1000
z = [[0 for m in range(pixel+1)] for n in range(pixel+1)]
for i in range(pixel+1):
    re = x_lower + (x_upper - x_lower)/pixel * i 
    for j in range(pixel+1):
        im = y_lower + (y_upper - y_lower)/pixel * j
        z[j][i] = J.Calc(re, im)

x = np.arange(pixel+1)
y = np.arange(pixel+1)
Z = np.array(z)
X, Y = np.meshgrid(x, y)

plt.rcParams['figure.figsize'] = 20,20
plt.gca().set_aspect('equal', adjustable='box')
plt.pcolor(X, Y, Z)
plt.hot()
plt.xlabel('Re', fontsize=22)
plt.ylabel('Im', fontsize=22)
plt.xticks(color="None")
plt.yticks(color="None")
plt.tick_params(length=0)
plt.show()
